# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramya1410/Data-Science-Internship/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem statement 1

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd

# %%
df = pd.read_csv('top50spotify.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    SerialNo.                       Track.Name    Artist.Name           Genre  \
# 0          1                         Señorita   Shawn Mendes    canadian pop
# 1          2                            China       Anuel AA  reggaeton flow
# 2          3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3          4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4          5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SerialNo.         50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
df.drop(df.columns[0],axis=1)
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
os.rename('top50spotify.csv','top50.csv')

# %%
df1 = df["Energy"].mean()
df1
# Out:
# 64.06

# %%
df['totaloflength']=df['Length.'].sum()
df
# Out:
#     SerialNo.                                         Track.Name  \
# 0           1                                           Señorita
# 1           2                                              China
# 2           3                      boyfriend (with Social House)
# 3           4                    Beautiful People (feat. Khalid)
# 4           5                        Goodbyes (Feat. Young Thug)
# 5           6                  I Don't Care (with Justin Bieber)
# 6           7                                             Ransom
# 7           8                                  How Do You Sleep?
# 8           9                              Old Town Road - Remix
# 9          10                                            bad guy
# 10         11                                           Callaita
# 11         12              Loco Contigo (feat. J. Balvin & Tyga)
# 12         13                                  Someone You Loved
# ...

# %%
df3 = df.groupby('Genre')
df3.first()
# Out:
#                   SerialNo.  \
# Genre
# atl hip hop              34
# australian pop           27
# big room                 36
# boy band                 39
# brostep                  46
# canadian hip hop         15
# canadian pop              1
# country rap               9
# dance pop                 3
# dfw rap                   5
# edm                      31
# electropop               10
# escape room              20
# latin                    17
# panamanian pop           14
# pop                       4
# pop house                21
# r&b en espanol           45
# reggaeton                11
# reggaeton flow            2
# trap music                7
#
#                                                          Track.Name  \
# Genre
# atl hip hop               The London (feat. J. Cole & Travis Scott)
# australian pop                                         Dance Monkey
# big room          Summer Days (feat. Macklemore & Patrick Stump ...
# ...

# %%
import numpy as np

# %%
df5 = df.groupby(['Artist.Name','Genre']).agg({'Genre': np.max})
df5
# Out:
#                                               Genre
# Artist.Name      Genre
# Ali Gatie        canadian hip hop  canadian hip hop
# Anuel AA         reggaeton flow      reggaeton flow
# Ariana Grande    dance pop                dance pop
# Bad Bunny        reggaeton                reggaeton
# Billie Eilish    electropop              electropop
# Chris Brown      dance pop                dance pop
# DJ Snake         dance pop                dance pop
# Daddy Yankee     latin                        latin
# Drake            canadian hip hop  canadian hip hop
# Ed Sheeran       pop                            pop
# J Balvin         latin                        latin
# Jhay Cortez      reggaeton flow      reggaeton flow
# Jonas Brothers   boy band                  boy band
# Katy Perry       dance pop                dance pop
# Khalid           pop                            pop
# Kygo             edm                            edm
# Lady Gaga        dance pop                dance pop
# ...

# %%
df5.max()
# Out:
# Genre    trap music
# dtype: object

# %%
df4 = df.groupby(['Artist.Name','Genre'])
df4.max()
# Out:
#                                    SerialNo.  \
# Artist.Name      Genre
# Ali Gatie        canadian hip hop         28
# Anuel AA         reggaeton flow            2
# Ariana Grande    dance pop                32
# Bad Bunny        reggaeton                11
# Billie Eilish    electropop               25
# Chris Brown      dance pop                16
# DJ Snake         dance pop                12
# Daddy Yankee     latin                    29
# Drake            canadian hip hop         15
# Ed Sheeran       pop                      50
# J Balvin         latin                    30
# Jhay Cortez      reggaeton flow           23
# Jonas Brothers   boy band                 39
# Katy Perry       dance pop                35
# Khalid           pop                      44
# Kygo             edm                      41
# Lady Gaga        dance pop                43
# Lauv             dance pop                40
# Lewis Capaldi    pop                      13
# ...

# %%
df4 = df.groupby(['Artist.Name','Genre']).size()
df4
# Out:
# Artist.Name       Genre
# Ali Gatie         canadian hip hop    1
# Anuel AA          reggaeton flow      1
# Ariana Grande     dance pop           2
# Bad Bunny         reggaeton           1
# Billie Eilish     electropop          2
# Chris Brown       dance pop           1
# DJ Snake          dance pop           1
# Daddy Yankee      latin               1
# Drake             canadian hip hop    1
# Ed Sheeran        pop                 4
# J Balvin          latin               2
# Jhay Cortez       reggaeton flow      1
# Jonas Brothers    boy band            1
# Katy Perry        dance pop           1
# Khalid            pop                 1
# Kygo              edm                 1
# Lady Gaga         dance pop           1
# Lauv              dance pop           1
# Lewis Capaldi     pop                 1
# Lil Nas X         country rap         2
# Lil Tecca         trap music          1
# Lizzo             escape room         1
# Lunay             latin               1
# ...

# %% [markdown]
# Problem statement 2

# %%
details = {'English':{'Sam':60,'Jackson':74,'Ahree':85},
'History':{'Gloria':83,'Sam':65,'Isla':78,'Aron':72,'Gray':61},
'Geography':{'Jackson':92,'Gloria':95,'Isla':82,'Aron':75,'Ahree':76},
'Mathematics':{'Sam':99,'Gloria':74,'Jackson':89,'Ahree':85,'Gray':95},
'Science':{'Sam':89,'Aron':82,'Gray':78,'Isla':93,'Ahree':87}
}

# %%
df = pd.DataFrame(details)
df
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        NaN         99.0     89.0
# Jackson     74.0      NaN       92.0         89.0      NaN
# Ahree       85.0      NaN       76.0         85.0     87.0
# Gloria       NaN     83.0       95.0         74.0      NaN
# Isla         NaN     78.0       82.0          NaN     93.0
# Aron         NaN     72.0       75.0          NaN     82.0
# Gray         NaN     61.0        NaN         95.0     78.0

# %%
df.isnull()
# Out:
#          English  History  Geography  Mathematics  Science
# Sam        False    False       True        False    False
# Jackson    False     True      False        False     True
# Ahree      False     True      False        False    False
# Gloria      True    False      False        False     True
# Isla        True    False      False         True    False
# Aron        True    False      False         True    False
# Gray        True    False       True        False    False

# %%
df.fillna("0",inplace = True)
df
# Out:
#         English History Geography Mathematics Science
# Sam        60.0    65.0         0        99.0    89.0
# Jackson    74.0       0      92.0        89.0       0
# Ahree      85.0       0      76.0        85.0    87.0
# Gloria        0    83.0      95.0        74.0       0
# Isla          0    78.0      82.0           0    93.0
# Aron          0    72.0      75.0           0    82.0
# Gray          0    61.0         0        95.0    78.0

# %%
df1 = df.transpose()
df1
# Out:
#               Sam Jackson Ahree Gloria  Isla  Aron  Gray
# English      60.0    74.0  85.0      0     0     0     0
# History      65.0       0     0   83.0  78.0  72.0  61.0
# Geography       0    92.0  76.0   95.0  82.0  75.0     0
# Mathematics  99.0    89.0  85.0   74.0     0     0  95.0
# Science      89.0       0  87.0      0  93.0  82.0  78.0

# %%
df
# Out:
#         English History Geography Mathematics Science
# Sam        60.0    65.0         0        99.0    89.0
# Jackson    74.0       0      92.0        89.0       0
# Ahree      85.0       0      76.0        85.0    87.0
# Gloria        0    83.0      95.0        74.0       0
# Isla          0    78.0      82.0           0    93.0
# Aron          0    72.0      75.0           0    82.0
# Gray          0    61.0         0        95.0    78.0

# %%
df = pd.DataFrame(details)
df
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        NaN         99.0     89.0
# Jackson     74.0      NaN       92.0         89.0      NaN
# Ahree       85.0      NaN       76.0         85.0     87.0
# Gloria       NaN     83.0       95.0         74.0      NaN
# Isla         NaN     78.0       82.0          NaN     93.0
# Aron         NaN     72.0       75.0          NaN     82.0
# Gray         NaN     61.0        NaN         95.0     78.0

# %%
df2 = df.copy()
df2["Average"] = df2.mean(numeric_only=True, axis=1)
df2
# Out:
#          English  History  Geography  Mathematics  Science    Average
# Sam         60.0     65.0        NaN         99.0     89.0  78.250000
# Jackson     74.0      NaN       92.0         89.0      NaN  85.000000
# Ahree       85.0      NaN       76.0         85.0     87.0  83.250000
# Gloria       NaN     83.0       95.0         74.0      NaN  84.000000
# Isla         NaN     78.0       82.0          NaN     93.0  84.333333
# Aron         NaN     72.0       75.0          NaN     82.0  76.333333
# Gray         NaN     61.0        NaN         95.0     78.0  78.000000

# %% [markdown]
# Problem statement 3

# %%
sr = pd.Series(range(1,1001))
sr.query('x')

# %%
sr = pd.Series(range(1,1001))
index_ = [x for x in sr if((x%7==0) | (x%17==0))]
sr.index=index_
print(sr)
res = sr.get(key = index_)
print(res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c154d680a4c8> in <module>
#       1 sr = pd.Series(range(1,1001))
#       2 index_ = [x for x in sr if((x%7==0) | (x%17==0))]
# ----> 3 sr.index=index_
#       4 print(sr)
#       5 res = sr.get(key = index_)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _set_axis(self, axis, labels, fastpath)
#     557         if not fastpath:
# ...

# %% [markdown]
# Problem statement 4

# %%
df = pd.read_csv('cereal.csv')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(17,17))
for group,data in df.groupby('name'):
  plt.barh(group,data['rating'])

# %%
plt.figure(figsize=(17,17))
for group,data in df.groupby('name'):
  plt.barh(group,data['rating'])
listOf_Xticks = np.arange(0, 100,2)
plt.xticks(listOf_Xticks)
listOf_Yticks = np.arange(0, 100)
plt.yticks(listOf_Yticks)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(17,17))
for group,data in df.groupby('name'):
  plt.barh(group,data['rating'])
x=df["rating"]
y=df["name"]
sns.set_style("darkgrid")
sns.stripplot(x="rating", y="name",data=df)
